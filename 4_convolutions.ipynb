# %% [markdown]
# Deep Learning
# =============
#
# Assignment 4
# ------------
#
# Previously in `2_fullyconnected.ipynb` and `3_regularization.ipynb`, we trained fully connected networks to classify [notMNIST](http://yaroslavvb.blogspot.com/2011/09/notmnist-dataset.html) characters.
#
# The goal of this assignment is make the neural network convolutional.

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
from __future__ import print_function
import numpy as np
import tensorflow as tf
from six.moves import cPickle as pickle
from six.moves import range

# %%
pickle_file = 'notMNIST.pickle'

with open(pickle_file, 'rb') as f:
  save = pickle.load(f)
  train_dataset = save['train_dataset']
  train_labels = save['train_labels']
  valid_dataset = save['valid_dataset']
  valid_labels = save['valid_labels']
  test_dataset = save['test_dataset']
  test_labels = save['test_labels']
  del save  # hint to help gc free up memory
  print('Training set', train_dataset.shape, train_labels.shape)
  print('Validation set', valid_dataset.shape, valid_labels.shape)
  print('Test set', test_dataset.shape, test_labels.shape)
# Out:
# Training set (50000, 28, 28) (50000,)
# Validation set (1000, 28, 28) (1000,)
# Test set (1000, 28, 28) (1000,)

# %% [markdown]
# Reformat into a TensorFlow-friendly shape:
# - convolutions need the image data formatted as a cube (width by height by #channels)
# - labels as float 1-hot encodings.

# %%
image_size = 28
num_labels = 10
num_channels = 1 # grayscale

import numpy as np

def reformat(dataset, labels):
  dataset = dataset.reshape(
    (-1, image_size, image_size, num_channels)).astype(np.float32)
  labels = (np.arange(num_labels) == labels[:,None]).astype(np.float32) # GREAT
  return dataset, labels
train_dataset, train_labels = reformat(train_dataset, train_labels)
valid_dataset, valid_labels = reformat(valid_dataset, valid_labels)
test_dataset, test_labels = reformat(test_dataset, test_labels)
print('Training set', train_dataset.shape, train_labels.shape)
print('Validation set', valid_dataset.shape, valid_labels.shape)
print('Test set', test_dataset.shape, test_labels.shape)
# Out:
# Training set (50000, 28, 28, 1) (50000, 10)
# Validation set (1000, 28, 28, 1) (1000, 10)
# Test set (1000, 28, 28, 1) (1000, 10)

# %%
def accuracy(predictions, labels):
  return (100.0 * np.sum(np.argmax(predictions, 1) == np.argmax(labels, 1))
          / predictions.shape[0])

# %% [markdown]
# Let's build a small network with two convolutional layers, followed by one fully connected layer. Convolutional networks are more expensive computationally, so we'll limit its depth and number of fully connected nodes.

# %%
batch_size = 16
patch_size = 5
depth = 16
num_hidden = 64

graph = tf.Graph()

with graph.as_default():

  # Input data.
  tf_train_dataset = tf.placeholder(
  tf.float32, shape=(batch_size, image_size, image_size, num_channels))
  tf_train_labels = tf.placeholder(tf.float32, shape=(batch_size, num_labels))
  tf_valid_dataset = tf.constant(valid_dataset)
  tf_test_dataset = tf.constant(test_dataset)
  
  # Variables.
  layer1_weights = tf.Variable(tf.truncated_normal(
      [patch_size, patch_size, num_channels, depth], stddev=0.1))
  layer1_biases = tf.Variable(tf.zeros([depth]))
  layer2_weights = tf.Variable(tf.truncated_normal(
      [patch_size, patch_size, depth, depth], stddev=0.1))
  layer2_biases = tf.Variable(tf.constant(1.0, shape=[depth]))
  layer3_weights = tf.Variable(tf.truncated_normal(
      [image_size // 4 * image_size // 4 * depth, num_hidden], stddev=0.1))
  layer3_biases = tf.Variable(tf.constant(1.0, shape=[num_hidden]))
  layer4_weights = tf.Variable(tf.truncated_normal(
      [num_hidden, num_labels], stddev=0.1))
  layer4_biases = tf.Variable(tf.constant(1.0, shape=[num_labels]))
  
  # Model.
  def model(data):
        
    conv = tf.nn.conv2d(data, layer1_weights, [1, 2, 2, 1], padding='SAME')
    hidden = tf.nn.relu(conv + layer1_biases)
    conv = tf.nn.conv2d(hidden, layer2_weights, [1, 2, 2, 1], padding='SAME')
    hidden = tf.nn.relu(conv + layer2_biases)
    shape = hidden.get_shape().as_list()
    reshape = tf.reshape(hidden, [shape[0], shape[1] * shape[2] * shape[3]])
    hidden = tf.nn.relu(tf.matmul(reshape, layer3_weights) + layer3_biases)
    return tf.matmul(hidden, layer4_weights) + layer4_biases
  
  # Training computation.
  logits = model(tf_train_dataset)
  loss = tf.reduce_mean(
    tf.nn.softmax_cross_entropy_with_logits(labels=tf_train_labels, logits=logits))
    
  # Optimizer.
  optimizer = tf.train.GradientDescentOptimizer(0.05).minimize(loss)
  
  # Predictions for the training, validation, and test data.
  train_prediction = tf.nn.softmax(logits)
  valid_prediction = tf.nn.softmax(model(tf_valid_dataset))
  test_prediction = tf.nn.softmax(model(tf_test_dataset))

# %%
num_steps = 1001

with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print('Initialized')
  for step in range(num_steps):
    offset = (step * batch_size) % (train_labels.shape[0] - batch_size)
    batch_data = train_dataset[offset:(offset + batch_size), :, :, :]
    batch_labels = train_labels[offset:(offset + batch_size), :]
    feed_dict = {tf_train_dataset : batch_data, tf_train_labels : batch_labels}
    _, l, predictions = session.run(
      [optimizer, loss, train_prediction], feed_dict=feed_dict)
    if (step % 50 == 0):
      print('Minibatch loss at step %d: %f' % (step, l))
      print('Minibatch accuracy: %.1f%%' % accuracy(predictions, batch_labels))
      print('Validation accuracy: %.1f%%' % accuracy(
        valid_prediction.eval(), valid_labels))
  print('Test accuracy: %.1f%%' % accuracy(test_prediction.eval(), test_labels))
# Out:
# Initialized
# Minibatch loss at step 0: 3.612476
# Minibatch accuracy: 6.2%
# Validation accuracy: 9.9%
# Minibatch loss at step 50: 1.254107
# Minibatch accuracy: 62.5%
# Validation accuracy: 63.3%
# Minibatch loss at step 100: 0.768677
# Minibatch accuracy: 75.0%
# Validation accuracy: 75.9%
# Minibatch loss at step 150: 0.396439
# Minibatch accuracy: 87.5%
# Validation accuracy: 77.0%
# Minibatch loss at step 200: 0.553280
# Minibatch accuracy: 87.5%
# Validation accuracy: 79.1%
# Minibatch loss at step 250: 0.455965
# Minibatch accuracy: 93.8%
# Validation accuracy: 79.2%
# Minibatch loss at step 300: 0.559049
# Minibatch accuracy: 81.2%
# Validation accuracy: 77.9%
# Minibatch loss at step 350: 0.831882
# Minibatch accuracy: 75.0%
# Validation accuracy: 78.5%
# Minibatch loss at step 400: 1.111696
# Minibatch accuracy: 62.5%
# Validation accuracy: 80.8%
# Minibatch loss at step 450: 0.733105
# Minibatch accuracy: 81.2%
# Validation accuracy: 81.2%
# Minibatch loss at step 500: 0.661429
# Minibatch accuracy: 87.5%
# Validation accuracy: 80.6%
# Minibatch loss at step 550: 0.490677
# Minibatch accuracy: 81.2%
# Validation accuracy: 80.5%
# Minibatch loss at step 600: 0.323948
# Minibatch accuracy: 93.8%
# Validation accuracy: 82.6%
# Minibatch loss at step 650: 0.853704
# Minibatch accuracy: 81.2%
# Validation accuracy: 81.9%
# Minibatch loss at step 700: 0.735617
# Minibatch accuracy: 81.2%
# Validation accuracy: 82.0%
# Minibatch loss at step 750: 0.437688
# Minibatch accuracy: 81.2%
# Validation accuracy: 82.6%
# Minibatch loss at step 800: 0.593354
# Minibatch accuracy: 87.5%
# Validation accuracy: 82.7%
# Minibatch loss at step 850: 0.762134
# Minibatch accuracy: 68.8%
# Validation accuracy: 84.1%
# Minibatch loss at step 900: 0.836288
# Minibatch accuracy: 81.2%
# Validation accuracy: 82.6%
# Minibatch loss at step 950: 0.478443
# Minibatch accuracy: 81.2%
# Validation accuracy: 82.6%
# Minibatch loss at step 1000: 0.149556
# Minibatch accuracy: 100.0%
# Validation accuracy: 83.2%
# Test accuracy: 90.2%

# %% [markdown]
# ---
# Problem 1
# ---------
#
# The convolutional model above uses convolutions with stride 2 to reduce the dimensionality. Replace the strides by a max pooling operation (`nn.max_pool()`) of stride 2 and kernel size 2.
#
# ---

# %%
batch_size = 16
patch_size = 5
depth = 16
num_hidden = 64

graph = tf.Graph()

with graph.as_default():

  # Input data.
  tf_train_dataset = tf.placeholder(
  tf.float32, shape=(batch_size, image_size, image_size, num_channels))
  tf_train_labels = tf.placeholder(tf.float32, shape=(batch_size, num_labels))
  tf_valid_dataset = tf.constant(valid_dataset)
  tf_test_dataset = tf.constant(test_dataset)
  
  # Variables.
  layer1_weights = tf.Variable(tf.truncated_normal(
      [patch_size, patch_size, num_channels, depth], stddev=0.1))
  layer1_biases = tf.Variable(tf.zeros([depth]))
  layer2_weights = tf.Variable(tf.truncated_normal(
      [patch_size, patch_size, depth, depth], stddev=0.1))
  layer2_biases = tf.Variable(tf.constant(1.0, shape=[depth]))
  layer3_weights = tf.Variable(tf.truncated_normal(
      [image_size // 4 * image_size // 4 * depth, num_hidden], stddev=0.1))
  layer3_biases = tf.Variable(tf.constant(1.0, shape=[num_hidden]))
  layer4_weights = tf.Variable(tf.truncated_normal(
      [num_hidden, num_labels], stddev=0.1))
  layer4_biases = tf.Variable(tf.constant(1.0, shape=[num_labels]))
  
  # Model.
  def model(data):
        
    conv1 = tf.nn.conv2d(data, layer1_weights, [1, 1, 1, 1], padding='SAME')
    bias1 = tf.nn.relu(conv1 + layer1_biases)
    pool1 = tf.nn.max_pool(bias1, [1, 2, 2, 1], [1, 2, 2, 1], padding='SAME')
    conv2 = tf.nn.conv2d(pool1, layer2_weights, [1, 1, 1, 1], padding='SAME')
    bias2 = tf.nn.relu(conv2 + layer2_biases)
    pool2 = tf.nn.max_pool(bias2, [1, 2, 2, 1], [1, 2, 2, 1], padding='SAME')
    shape = pool2.get_shape().as_list()
    reshape = tf.reshape(pool2, [shape[0], shape[1] * shape[2] * shape[3]])
    hidden = tf.nn.relu(tf.matmul(reshape, layer3_weights) + layer3_biases)
    return tf.matmul(hidden, layer4_weights) + layer4_biases
  
  # Training computation.
  logits = model(tf_train_dataset)
  loss = tf.reduce_mean(
    tf.nn.softmax_cross_entropy_with_logits(labels=tf_train_labels, logits=logits))
    
  # Optimizer.
  optimizer = tf.train.GradientDescentOptimizer(0.05).minimize(loss)
  
  # Predictions for the training, validation, and test data.
  train_prediction = tf.nn.softmax(logits)
  valid_prediction = tf.nn.softmax(model(tf_valid_dataset))
  test_prediction = tf.nn.softmax(model(tf_test_dataset))

# %%
num_steps = 1001

with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print('Initialized')
  for step in range(num_steps):
    offset = (step * batch_size) % (train_labels.shape[0] - batch_size)
    batch_data = train_dataset[offset:(offset + batch_size), :, :, :]
    batch_labels = train_labels[offset:(offset + batch_size), :]
    feed_dict = {tf_train_dataset : batch_data, tf_train_labels : batch_labels}
    _, l, predictions = session.run(
      [optimizer, loss, train_prediction], feed_dict=feed_dict)
    if (step % 50 == 0):
      print('Minibatch loss at step %d: %f' % (step, l))
      print('Minibatch accuracy: %.1f%%' % accuracy(predictions, batch_labels))
      print('Validation accuracy: %.1f%%' % accuracy(
        valid_prediction.eval(), valid_labels))
  print('Test accuracy: %.1f%%' % accuracy(test_prediction.eval(), test_labels))
# Out:
# Initialized
# Minibatch loss at step 0: 4.694088
# Minibatch accuracy: 6.2%
# Validation accuracy: 10.0%
# Minibatch loss at step 50: 1.993816
# Minibatch accuracy: 18.8%
# Validation accuracy: 37.5%
# Minibatch loss at step 100: 1.127942
# Minibatch accuracy: 50.0%
# Validation accuracy: 53.2%
# Minibatch loss at step 150: 0.736733
# Minibatch accuracy: 75.0%
# Validation accuracy: 72.0%
# Minibatch loss at step 200: 0.837088
# Minibatch accuracy: 81.2%
# Validation accuracy: 70.5%
# Minibatch loss at step 250: 0.479388
# Minibatch accuracy: 81.2%
# Validation accuracy: 77.1%
# Minibatch loss at step 300: 0.511701
# Minibatch accuracy: 87.5%
# Validation accuracy: 75.5%
# Minibatch loss at step 350: 0.799758
# Minibatch accuracy: 68.8%
# Validation accuracy: 78.3%
# Minibatch loss at step 400: 0.873569
# Minibatch accuracy: 68.8%
# Validation accuracy: 79.9%
# Minibatch loss at step 450: 0.796326
# Minibatch accuracy: 75.0%
# Validation accuracy: 81.5%
# Minibatch loss at step 500: 0.643363
# Minibatch accuracy: 81.2%
# Validation accuracy: 80.7%
# Minibatch loss at step 550: 0.507032
# Minibatch accuracy: 87.5%
# Validation accuracy: 80.1%
# Minibatch loss at step 600: 0.292451
# Minibatch accuracy: 93.8%
# Validation accuracy: 82.0%
# Minibatch loss at step 650: 0.705938
# Minibatch accuracy: 81.2%
# Validation accuracy: 81.5%
# Minibatch loss at step 700: 0.727144
# Minibatch accuracy: 81.2%
# Validation accuracy: 81.7%
# Minibatch loss at step 750: 0.380965
# Minibatch accuracy: 87.5%
# Validation accuracy: 83.1%
# Minibatch loss at step 800: 0.619266
# Minibatch accuracy: 81.2%
# Validation accuracy: 83.7%
# Minibatch loss at step 850: 0.752005
# Minibatch accuracy: 68.8%
# Validation accuracy: 84.8%
# Minibatch loss at step 900: 0.716903
# Minibatch accuracy: 81.2%
# Validation accuracy: 83.9%
# Minibatch loss at step 950: 0.420309
# Minibatch accuracy: 81.2%
# Validation accuracy: 83.3%
# Minibatch loss at step 1000: 0.166552
# Minibatch accuracy: 100.0%
# Validation accuracy: 83.5%
# Test accuracy: 90.5%

# %% [markdown]
# ---
# Problem 2
# ---------
#
# Try to get the best performance you can using a convolutional net. Look for example at the classic [LeNet5](http://yann.lecun.com/exdb/lenet/) architecture, adding Dropout, and/or adding learning rate decay.
#
# ---

# %% [markdown]
# The CNN below is loosely inspired by the LeNet5 architecture

# %%
batch_size = 16
patch_size = 5
depth = 16
num_hidden = 64

graph = tf.Graph()

with graph.as_default():

  # Input data.
  tf_train_dataset = tf.placeholder(
  tf.float32, shape=(batch_size, image_size, image_size, num_channels))
  tf_train_labels = tf.placeholder(tf.float32, shape=(batch_size, num_labels))
  tf_valid_dataset = tf.constant(valid_dataset)
  tf_test_dataset = tf.constant(test_dataset)
  
  # Variables.
  layer1_weights = tf.Variable(tf.truncated_normal(
      [patch_size, patch_size, num_channels, depth], stddev=0.1))
  layer1_biases = tf.Variable(tf.zeros([depth]))
  layer2_weights = tf.Variable(tf.truncated_normal(
      [patch_size, patch_size, depth, depth], stddev=0.1))
  layer2_biases = tf.Variable(tf.constant(1.0, shape=[depth]))
  size3 = ((image_size - patch_size + 1) // 2 - patch_size + 1) // 2
  layer3_weights = tf.Variable(tf.truncated_normal(
      [size3 * size3 * depth, num_hidden], stddev=0.1))
  layer3_biases = tf.Variable(tf.constant(1.0, shape=[num_hidden]))
  layer4_weights = tf.Variable(tf.truncated_normal(
      [num_hidden, num_labels], stddev=0.1))
  layer4_biases = tf.Variable(tf.constant(1.0, shape=[num_labels]))
  
  # Model.
  def model(data):
    # C1 input 28 * 28  
    conv1 = tf.nn.conv2d(data, layer1_weights, [1, 1, 1, 1], padding='VALID')
    bias1 = tf.nn.relu(conv1 + layer1_biases)
    # S2 input 24 * 24
    pool2 = tf.nn.avg_pool(bias1, [1, 2, 2, 1], [1, 2, 2, 1], padding='VALID')
    # C3 input 12 * 12
    conv3 = tf.nn.conv2d(pool2, layer2_weights, [1, 1, 1, 1], padding='VALID')
    bias3 = tf.nn.relu(conv3 + layer2_biases)
    # S4 input 8 * 8
    pool4 = tf.nn.max_pool(bias3, [1, 2, 2, 1], [1, 2, 2, 1], padding='VALID')
    # F6 input 4 * 4
    shape = pool4.get_shape().as_list()
    reshape = tf.reshape(pool4, [shape[0], shape[1] * shape[2] * shape[3]])
    hidden = tf.nn.relu(tf.matmul(reshape, layer3_weights) + layer3_biases)
    return tf.matmul(hidden, layer4_weights) + layer4_biases
  
  # Training computation.
  logits = model(tf_train_dataset)
  loss = tf.reduce_mean(
    tf.nn.softmax_cross_entropy_with_logits(labels=tf_train_labels, logits=logits))
    
  # Optimizer.
  optimizer = tf.train.GradientDescentOptimizer(0.05).minimize(loss)
  
  # Predictions for the training, validation, and test data.
  train_prediction = tf.nn.softmax(logits)
  valid_prediction = tf.nn.softmax(model(tf_valid_dataset))
  test_prediction = tf.nn.softmax(model(tf_test_dataset))

# %%
num_steps = 20001

with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print('Initialized')
  for step in range(num_steps):
    offset = (step * batch_size) % (train_labels.shape[0] - batch_size)
    batch_data = train_dataset[offset:(offset + batch_size), :, :, :]
    batch_labels = train_labels[offset:(offset + batch_size), :]
    feed_dict = {tf_train_dataset : batch_data, tf_train_labels : batch_labels}
    _, l, predictions = session.run(
      [optimizer, loss, train_prediction], feed_dict=feed_dict)
    if (step % 50 == 0):
      print('Minibatch loss at step %d: %f' % (step, l))
      print('Minibatch accuracy: %.1f%%' % accuracy(predictions, batch_labels))
      print('Validation accuracy: %.1f%%' % accuracy(
        valid_prediction.eval(), valid_labels))
  print('Test accuracy: %.1f%%' % accuracy(test_prediction.eval(), test_labels))
# Out:
# Initialized
# Minibatch loss at step 0: 3.070329
# Minibatch accuracy: 6.2%
# Validation accuracy: 10.0%
# Minibatch loss at step 50: 1.476573
# Minibatch accuracy: 56.2%
# Validation accuracy: 47.3%
# Minibatch loss at step 100: 0.922621
# Minibatch accuracy: 68.8%
# Validation accuracy: 61.8%
# Minibatch loss at step 150: 0.887097
# Minibatch accuracy: 75.0%
# Validation accuracy: 72.5%
# Minibatch loss at step 200: 0.915151
# Minibatch accuracy: 62.5%
# Validation accuracy: 72.6%
# Minibatch loss at step 250: 0.683716
# Minibatch accuracy: 87.5%
# Validation accuracy: 75.2%
# Minibatch loss at step 300: 0.562267
# Minibatch accuracy: 87.5%
# Validation accuracy: 78.1%
# Minibatch loss at step 350: 0.657585
# Minibatch accuracy: 81.2%
# Validation accuracy: 79.1%
# Minibatch loss at step 400: 1.218035
# Minibatch accuracy: 56.2%
# Validation accuracy: 79.9%
# Minibatch loss at step 450: 0.829881
# Minibatch accuracy: 81.2%
# Validation accuracy: 79.5%
# Minibatch loss at step 500: 0.629294
# Minibatch accuracy: 75.0%
# Validation accuracy: 78.9%
# Minibatch loss at step 550: 0.565569
# Minibatch accuracy: 87.5%
# Validation accuracy: 79.3%
# Minibatch loss at step 600: 0.322207
# Minibatch accuracy: 87.5%
# Validation accuracy: 81.0%
# Minibatch loss at step 650: 0.800781
# Minibatch accuracy: 81.2%
# Validation accuracy: 80.4%
# Minibatch loss at step 700: 0.695275
# Minibatch accuracy: 75.0%
# Validation accuracy: 80.6%
# Minibatch loss at step 750: 0.660700
# Minibatch accuracy: 81.2%
# Validation accuracy: 81.0%
# Minibatch loss at step 800: 0.626943
# Minibatch accuracy: 87.5%
# Validation accuracy: 82.5%
# Minibatch loss at step 850: 0.972491
# Minibatch accuracy: 75.0%
# Validation accuracy: 82.9%
# Minibatch loss at step 900: 0.969502
# Minibatch accuracy: 68.8%
# Validation accuracy: 80.6%
# Minibatch loss at step 950: 0.652616
# Minibatch accuracy: 81.2%
# Validation accuracy: 82.3%
# Minibatch loss at step 1000: 0.338698
# Minibatch accuracy: 93.8%
# Validation accuracy: 82.1%
# Minibatch loss at step 1050: 0.784915
# Minibatch accuracy: 81.2%
# Validation accuracy: 81.5%
# Minibatch loss at step 1100: 0.859125
# Minibatch accuracy: 75.0%
# Validation accuracy: 81.3%
# Minibatch loss at step 1150: 0.447343
# Minibatch accuracy: 87.5%
# Validation accuracy: 83.2%
# Minibatch loss at step 1200: 0.897131
# Minibatch accuracy: 81.2%
# Validation accuracy: 83.5%
# Minibatch loss at step 1250: 0.365896
# Minibatch accuracy: 81.2%
# Validation accuracy: 81.7%
# Minibatch loss at step 1300: 0.409749
# Minibatch accuracy: 87.5%
# Validation accuracy: 82.4%
# Minibatch loss at step 1350: 0.463343
# Minibatch accuracy: 87.5%
# Validation accuracy: 83.9%
# Minibatch loss at step 1400: 1.024221
# Minibatch accuracy: 75.0%
# Validation accuracy: 82.8%
# Minibatch loss at step 1450: 0.800089
# Minibatch accuracy: 81.2%
# Validation accuracy: 84.7%
# Minibatch loss at step 1500: 0.593772
# Minibatch accuracy: 81.2%
# Validation accuracy: 84.0%
# Minibatch loss at step 1550: 0.539414
# Minibatch accuracy: 81.2%
# Validation accuracy: 83.6%
# Minibatch loss at step 1600: 0.933996
# Minibatch accuracy: 62.5%
# Validation accuracy: 84.9%
# Minibatch loss at step 1650: 0.508383
# Minibatch accuracy: 87.5%
# Validation accuracy: 84.3%
# Minibatch loss at step 1700: 1.262218
# Minibatch accuracy: 56.2%
# Validation accuracy: 85.7%
# Minibatch loss at step 1750: 0.792347
# Minibatch accuracy: 81.2%
# Validation accuracy: 84.1%
# Minibatch loss at step 1800: 0.684313
# Minibatch accuracy: 75.0%
# Validation accuracy: 84.8%
# Minibatch loss at step 1850: 0.417633
# Minibatch accuracy: 87.5%
# Validation accuracy: 85.9%
# Minibatch loss at step 1900: 0.590213
# Minibatch accuracy: 81.2%
# Validation accuracy: 84.1%
# Minibatch loss at step 1950: 0.638287
# Minibatch accuracy: 81.2%
# Validation accuracy: 85.1%
# Minibatch loss at step 2000: 0.279646
# Minibatch accuracy: 93.8%
# Validation accuracy: 86.5%
# Minibatch loss at step 2050: 0.549494
# Minibatch accuracy: 87.5%
# Validation accuracy: 85.3%
# Minibatch loss at step 2100: 0.880985
# Minibatch accuracy: 75.0%
# Validation accuracy: 85.8%
# Minibatch loss at step 2150: 0.979588
# Minibatch accuracy: 68.8%
# Validation accuracy: 86.2%
# Minibatch loss at step 2200: 0.836591
# Minibatch accuracy: 62.5%
# Validation accuracy: 86.3%
# Minibatch loss at step 2250: 0.707975
# Minibatch accuracy: 75.0%
# Validation accuracy: 84.0%
# Minibatch loss at step 2300: 0.825097
# Minibatch accuracy: 68.8%
# Validation accuracy: 85.6%
# Minibatch loss at step 2350: 0.892524
# Minibatch accuracy: 68.8%
# Validation accuracy: 85.3%
# Minibatch loss at step 2400: 0.333587
# Minibatch accuracy: 87.5%
# Validation accuracy: 85.8%
# Minibatch loss at step 2450: 0.525535
# Minibatch accuracy: 81.2%
# Validation accuracy: 86.3%
# Minibatch loss at step 2500: 0.600206
# Minibatch accuracy: 75.0%
# Validation accuracy: 84.7%
# Minibatch loss at step 2550: 0.502842
# Minibatch accuracy: 87.5%
# Validation accuracy: 86.2%
# Minibatch loss at step 2600: 0.652360
# Minibatch accuracy: 81.2%
# Validation accuracy: 86.5%
# Minibatch loss at step 2650: 1.013160
# Minibatch accuracy: 68.8%
# Validation accuracy: 85.7%
# Minibatch loss at step 2700: 0.321780
# Minibatch accuracy: 87.5%
# Validation accuracy: 84.3%
# Minibatch loss at step 2750: 0.072418
# Minibatch accuracy: 100.0%
# Validation accuracy: 86.9%
# Minibatch loss at step 2800: 0.728011
# Minibatch accuracy: 68.8%
# Validation accuracy: 86.1%
# Minibatch loss at step 2850: 0.386752
# Minibatch accuracy: 87.5%
# Validation accuracy: 85.9%
# Minibatch loss at step 2900: 0.113582
# Minibatch accuracy: 93.8%
# Validation accuracy: 85.9%
# Minibatch loss at step 2950: 0.266418
# Minibatch accuracy: 87.5%
# Validation accuracy: 85.9%
# Minibatch loss at step 3000: 0.127817
# Minibatch accuracy: 93.8%
# Validation accuracy: 86.0%
# Minibatch loss at step 3050: 0.659954
# Minibatch accuracy: 75.0%
# Validation accuracy: 87.5%
# Minibatch loss at step 3100: 0.222175
# Minibatch accuracy: 93.8%
# Validation accuracy: 86.2%
# Minibatch loss at step 3150: 0.583387
# Minibatch accuracy: 87.5%
# Validation accuracy: 86.8%
# Minibatch loss at step 3200: 0.009250
# Minibatch accuracy: 100.0%
# Validation accuracy: 86.1%
# Minibatch loss at step 3250: 0.197052
# Minibatch accuracy: 87.5%
# Validation accuracy: 86.9%
# Minibatch loss at step 3300: 0.095621
# Minibatch accuracy: 100.0%
# Validation accuracy: 86.8%
# Minibatch loss at step 3350: 0.598404
# Minibatch accuracy: 75.0%
# Validation accuracy: 85.8%
# Minibatch loss at step 3400: 0.469143
# Minibatch accuracy: 75.0%
# Validation accuracy: 86.8%
# Minibatch loss at step 3450: 0.251471
# Minibatch accuracy: 93.8%
# Validation accuracy: 87.7%
# Minibatch loss at step 3500: 0.341861
# Minibatch accuracy: 93.8%
# Validation accuracy: 86.7%
# Minibatch loss at step 3550: 0.875145
# Minibatch accuracy: 75.0%
# Validation accuracy: 87.2%
# Minibatch loss at step 3600: 0.071846
# Minibatch accuracy: 93.8%
# Validation accuracy: 87.1%
# Minibatch loss at step 3650: 0.129133
# Minibatch accuracy: 100.0%
# Validation accuracy: 86.4%
# Minibatch loss at step 3700: 0.757912
# Minibatch accuracy: 81.2%
# Validation accuracy: 87.6%
# Minibatch loss at step 3750: 0.442127
# Minibatch accuracy: 87.5%
# Validation accuracy: 86.2%
# Minibatch loss at step 3800: 0.305020
# Minibatch accuracy: 93.8%
# Validation accuracy: 86.5%
# Minibatch loss at step 3850: 0.086558
# Minibatch accuracy: 93.8%
# Validation accuracy: 87.5%
# Minibatch loss at step 3900: 0.703458
# Minibatch accuracy: 68.8%
# Validation accuracy: 87.1%
# Minibatch loss at step 3950: 0.499266
# Minibatch accuracy: 81.2%
# Validation accuracy: 87.2%
# Minibatch loss at step 4000: 0.410117
# Minibatch accuracy: 93.8%
# Validation accuracy: 87.5%
# Minibatch loss at step 4050: 0.470591
# Minibatch accuracy: 81.2%
# Validation accuracy: 87.6%
# Minibatch loss at step 4100: 0.263787
# Minibatch accuracy: 93.8%
# Validation accuracy: 87.7%
# Minibatch loss at step 4150: 0.339604
# Minibatch accuracy: 87.5%
# Validation accuracy: 87.0%
# Minibatch loss at step 4200: 0.440775
# Minibatch accuracy: 81.2%
# Validation accuracy: 87.9%
# Minibatch loss at step 4250: 0.565381
# Minibatch accuracy: 81.2%
# Validation accuracy: 88.4%
# Minibatch loss at step 4300: 0.303345
# Minibatch accuracy: 87.5%
# Validation accuracy: 87.0%
# Minibatch loss at step 4350: 0.954015
# Minibatch accuracy: 75.0%
# Validation accuracy: 87.3%
# Minibatch loss at step 4400: 0.267287
# Minibatch accuracy: 93.8%
# Validation accuracy: 86.6%
# Minibatch loss at step 4450: 0.346047
# Minibatch accuracy: 93.8%
# Validation accuracy: 87.9%
# Minibatch loss at step 4500: 0.660583
# Minibatch accuracy: 75.0%
# Validation accuracy: 88.2%
# Minibatch loss at step 4550: 0.554856
# Minibatch accuracy: 87.5%
# Validation accuracy: 87.2%
# Minibatch loss at step 4600: 0.546818
# Minibatch accuracy: 87.5%
# Validation accuracy: 86.0%
# Minibatch loss at step 4650: 0.316674
# Minibatch accuracy: 87.5%
# Validation accuracy: 86.5%
# Minibatch loss at step 4700: 0.895544
# Minibatch accuracy: 68.8%
# Validation accuracy: 87.1%
# Minibatch loss at step 4750: 0.349837
# Minibatch accuracy: 81.2%
# Validation accuracy: 88.6%
# Minibatch loss at step 4800: 0.110192
# Minibatch accuracy: 100.0%
# Validation accuracy: 88.2%
# Minibatch loss at step 4850: 0.223878
# Minibatch accuracy: 93.8%
# Validation accuracy: 88.3%
# Minibatch loss at step 4900: 0.526991
# Minibatch accuracy: 81.2%
# Validation accuracy: 87.9%
# Minibatch loss at step 4950: 0.220140
# Minibatch accuracy: 87.5%
# Validation accuracy: 87.9%
# Minibatch loss at step 5000: 0.326596
# Minibatch accuracy: 93.8%
# Validation accuracy: 88.1%
# Minibatch loss at step 5050: 0.418950
# Minibatch accuracy: 87.5%
# Validation accuracy: 87.4%
# Minibatch loss at step 5100: 0.540029
# Minibatch accuracy: 75.0%
# Validation accuracy: 88.0%
# Minibatch loss at step 5150: 0.530271
# Minibatch accuracy: 81.2%
# Validation accuracy: 87.0%
# Minibatch loss at step 5200: 0.105495
# Minibatch accuracy: 100.0%
# Validation accuracy: 88.1%
# Minibatch loss at step 5250: 0.643461
# Minibatch accuracy: 87.5%
# Validation accuracy: 87.9%
# Minibatch loss at step 5300: 0.512069
# Minibatch accuracy: 87.5%
# Validation accuracy: 87.3%
# Minibatch loss at step 5350: 0.368925
# Minibatch accuracy: 87.5%
# Validation accuracy: 87.6%
# Minibatch loss at step 5400: 0.724384
# Minibatch accuracy: 68.8%
# Validation accuracy: 87.3%
# Minibatch loss at step 5450: 0.753933
# Minibatch accuracy: 87.5%
# Validation accuracy: 86.5%
# Minibatch loss at step 5500: 0.444630
# Minibatch accuracy: 87.5%
# Validation accuracy: 87.7%
# Minibatch loss at step 5550: 0.146032
# Minibatch accuracy: 100.0%
# Validation accuracy: 88.5%
# Minibatch loss at step 5600: 0.726252
# Minibatch accuracy: 75.0%
# Validation accuracy: 88.1%
# Minibatch loss at step 5650: 0.302653
# Minibatch accuracy: 87.5%
# Validation accuracy: 88.0%
# Minibatch loss at step 5700: 0.334116
# Minibatch accuracy: 93.8%
# Validation accuracy: 88.4%
# Minibatch loss at step 5750: 0.382816
# Minibatch accuracy: 93.8%
# Validation accuracy: 87.4%
# Minibatch loss at step 5800: 0.198770
# Minibatch accuracy: 100.0%
# Validation accuracy: 88.2%
# Minibatch loss at step 5850: 0.027723
# Minibatch accuracy: 100.0%
# Validation accuracy: 87.8%
# Minibatch loss at step 5900: 0.227268
# Minibatch accuracy: 93.8%
# Validation accuracy: 88.0%
# Minibatch loss at step 5950: 1.049670
# Minibatch accuracy: 75.0%
# Validation accuracy: 87.5%
# Minibatch loss at step 6000: 0.725861
# Minibatch accuracy: 87.5%
# Validation accuracy: 87.8%
# Minibatch loss at step 6050: 0.338815
# Minibatch accuracy: 87.5%
# Validation accuracy: 87.7%
# Minibatch loss at step 6100: 0.531941
# Minibatch accuracy: 81.2%
# Validation accuracy: 88.4%
# Minibatch loss at step 6150: 0.593199
# Minibatch accuracy: 81.2%
# Validation accuracy: 87.9%
# Minibatch loss at step 6200: 0.769334
# Minibatch accuracy: 68.8%
# Validation accuracy: 88.5%
# Minibatch loss at step 6250: 0.182203
# Minibatch accuracy: 100.0%
# Validation accuracy: 88.0%
# Minibatch loss at step 6300: 0.024209
# Minibatch accuracy: 100.0%
# Validation accuracy: 88.5%
# Minibatch loss at step 6350: 0.201572
# Minibatch accuracy: 87.5%
# Validation accuracy: 87.9%
# Minibatch loss at step 6400: 0.616806
# Minibatch accuracy: 87.5%
# Validation accuracy: 87.4%
# Minibatch loss at step 6450: 0.078580
# Minibatch accuracy: 100.0%
# Validation accuracy: 87.9%
# Minibatch loss at step 6500: 0.624070
# Minibatch accuracy: 81.2%
# Validation accuracy: 88.1%
# Minibatch loss at step 6550: 0.386494
# Minibatch accuracy: 87.5%
# Validation accuracy: 88.1%
# Minibatch loss at step 6600: 0.608450
# Minibatch accuracy: 75.0%
# Validation accuracy: 87.2%
# Minibatch loss at step 6650: 0.649568
# Minibatch accuracy: 81.2%
# Validation accuracy: 88.3%
# Minibatch loss at step 6700: 0.639933
# Minibatch accuracy: 81.2%
# Validation accuracy: 87.6%
# Minibatch loss at step 6750: 0.291146
# Minibatch accuracy: 93.8%
# Validation accuracy: 87.8%
# Minibatch loss at step 6800: 0.694339
# Minibatch accuracy: 81.2%
# Validation accuracy: 88.5%
# Minibatch loss at step 6850: 0.209716
# Minibatch accuracy: 93.8%
# Validation accuracy: 87.8%
# Minibatch loss at step 6900: 0.336800
# Minibatch accuracy: 87.5%
# Validation accuracy: 87.6%
# Minibatch loss at step 6950: 0.666660
# Minibatch accuracy: 81.2%
# Validation accuracy: 88.1%
# Minibatch loss at step 7000: 0.432302
# Minibatch accuracy: 87.5%
# Validation accuracy: 88.0%
# Minibatch loss at step 7050: 0.352216
# Minibatch accuracy: 87.5%
# Validation accuracy: 86.8%
# Minibatch loss at step 7100: 0.046271
# Minibatch accuracy: 100.0%
# Validation accuracy: 88.1%
# Minibatch loss at step 7150: 0.454631
# Minibatch accuracy: 81.2%
# Validation accuracy: 88.4%
# Minibatch loss at step 7200: 0.210713
# Minibatch accuracy: 93.8%
# Validation accuracy: 87.3%
# Minibatch loss at step 7250: 0.481809
# Minibatch accuracy: 87.5%
# Validation accuracy: 88.3%
# Minibatch loss at step 7300: 0.831912
# Minibatch accuracy: 68.8%
# Validation accuracy: 88.1%
# Minibatch loss at step 7350: 0.079909
# Minibatch accuracy: 100.0%
# Validation accuracy: 88.3%
# Minibatch loss at step 7400: 0.568147
# Minibatch accuracy: 81.2%
# Validation accuracy: 87.6%
# Minibatch loss at step 7450: 0.443568
# Minibatch accuracy: 81.2%
# Validation accuracy: 88.6%
# Minibatch loss at step 7500: 0.159504
# Minibatch accuracy: 93.8%
# Validation accuracy: 88.0%
# Minibatch loss at step 7550: 0.257482
# Minibatch accuracy: 93.8%
# Validation accuracy: 87.8%
# Minibatch loss at step 7600: 0.099243
# Minibatch accuracy: 100.0%
# Validation accuracy: 88.5%
# Minibatch loss at step 7650: 1.109513
# Minibatch accuracy: 75.0%
# Validation accuracy: 87.6%
# Minibatch loss at step 7700: 0.990892
# Minibatch accuracy: 68.8%
# Validation accuracy: 88.8%
# Minibatch loss at step 7750: 1.002156
# Minibatch accuracy: 68.8%
# Validation accuracy: 88.7%
# Minibatch loss at step 7800: 0.528464
# Minibatch accuracy: 81.2%
# Validation accuracy: 88.5%
# Minibatch loss at step 7850: 0.217567
# Minibatch accuracy: 93.8%
# Validation accuracy: 88.5%
# Minibatch loss at step 7900: 0.376413
# Minibatch accuracy: 93.8%
# Validation accuracy: 88.4%
# Minibatch loss at step 7950: 0.309728
# Minibatch accuracy: 93.8%
# Validation accuracy: 88.8%
# Minibatch loss at step 8000: 0.154755
# Minibatch accuracy: 93.8%
# Validation accuracy: 88.9%
# Minibatch loss at step 8050: 0.884389
# Minibatch accuracy: 75.0%
# Validation accuracy: 88.5%
# Minibatch loss at step 8100: 0.794252
# Minibatch accuracy: 75.0%
# Validation accuracy: 89.1%
# Minibatch loss at step 8150: 0.155735
# Minibatch accuracy: 93.8%
# Validation accuracy: 88.2%
# Minibatch loss at step 8200: 0.293961
# Minibatch accuracy: 93.8%
# Validation accuracy: 89.3%
# Minibatch loss at step 8250: 0.225321
# Minibatch accuracy: 93.8%
# Validation accuracy: 88.4%
# Minibatch loss at step 8300: 0.241832
# Minibatch accuracy: 93.8%
# Validation accuracy: 89.1%
# Minibatch loss at step 8350: 0.623066
# Minibatch accuracy: 81.2%
# Validation accuracy: 88.3%
# Minibatch loss at step 8400: 0.848755
# Minibatch accuracy: 68.8%
# Validation accuracy: 88.9%
# Minibatch loss at step 8450: 0.078241
# Minibatch accuracy: 100.0%
# Validation accuracy: 88.7%
# Minibatch loss at step 8500: 0.175044
# Minibatch accuracy: 93.8%
# Validation accuracy: 88.0%
# Minibatch loss at step 8550: 0.049394
# Minibatch accuracy: 100.0%
# Validation accuracy: 88.3%
# Minibatch loss at step 8600: 0.353521
# Minibatch accuracy: 87.5%
# Validation accuracy: 89.0%
# Minibatch loss at step 8650: 0.466551
# Minibatch accuracy: 87.5%
# Validation accuracy: 88.2%
# Minibatch loss at step 8700: 0.407830
# Minibatch accuracy: 87.5%
# Validation accuracy: 88.5%
# Minibatch loss at step 8750: 0.915981
# Minibatch accuracy: 68.8%
# Validation accuracy: 87.5%
# Minibatch loss at step 8800: 0.616135
# Minibatch accuracy: 87.5%
# Validation accuracy: 88.6%
# Minibatch loss at step 8850: 0.343720
# Minibatch accuracy: 81.2%
# Validation accuracy: 88.3%
# Minibatch loss at step 8900: 0.589048
# Minibatch accuracy: 87.5%
# Validation accuracy: 88.5%
# Minibatch loss at step 8950: 0.625712
# Minibatch accuracy: 81.2%
# Validation accuracy: 87.9%
# Minibatch loss at step 9000: 0.214135
# Minibatch accuracy: 93.8%
# Validation accuracy: 88.4%
# Minibatch loss at step 9050: 0.667095
# Minibatch accuracy: 68.8%
# Validation accuracy: 88.4%
# Minibatch loss at step 9100: 0.388048
# Minibatch accuracy: 81.2%
# Validation accuracy: 89.5%
# Minibatch loss at step 9150: 0.546659
# Minibatch accuracy: 81.2%
# Validation accuracy: 89.3%
# Minibatch loss at step 9200: 0.899865
# Minibatch accuracy: 87.5%
# Validation accuracy: 87.6%
# Minibatch loss at step 9250: 0.516551
# Minibatch accuracy: 75.0%
# Validation accuracy: 88.2%
# Minibatch loss at step 9300: 0.225287
# Minibatch accuracy: 93.8%
# Validation accuracy: 87.8%
# Minibatch loss at step 9350: 0.348853
# Minibatch accuracy: 81.2%
# Validation accuracy: 88.0%
# Minibatch loss at step 9400: 0.054997
# Minibatch accuracy: 100.0%
# Validation accuracy: 88.0%
# Minibatch loss at step 9450: 0.843185
# Minibatch accuracy: 75.0%
# Validation accuracy: 88.8%
# Minibatch loss at step 9500: 0.636735
# Minibatch accuracy: 87.5%
# Validation accuracy: 88.1%
# Minibatch loss at step 9550: 0.280458
# Minibatch accuracy: 93.8%
# Validation accuracy: 88.8%
# Minibatch loss at step 9600: 0.935288
# Minibatch accuracy: 81.2%
# Validation accuracy: 88.5%
# Minibatch loss at step 9650: 0.157083
# Minibatch accuracy: 100.0%
# Validation accuracy: 88.3%
# Minibatch loss at step 9700: 0.382872
# Minibatch accuracy: 87.5%
# Validation accuracy: 87.8%
# Minibatch loss at step 9750: 0.372770
# Minibatch accuracy: 87.5%
# Validation accuracy: 88.4%
# Minibatch loss at step 9800: 0.601359
# Minibatch accuracy: 87.5%
# Validation accuracy: 87.6%
# Minibatch loss at step 9850: 0.508368
# Minibatch accuracy: 87.5%
# Validation accuracy: 88.3%
# Minibatch loss at step 9900: 0.927022
# Minibatch accuracy: 81.2%
# Validation accuracy: 88.9%
# Minibatch loss at step 9950: 0.288707
# Minibatch accuracy: 87.5%
# Validation accuracy: 88.4%
# Minibatch loss at step 10000: 0.017740
# Minibatch accuracy: 100.0%
# Validation accuracy: 88.1%
# Minibatch loss at step 10050: 0.373645
# Minibatch accuracy: 81.2%
# Validation accuracy: 87.9%
# Minibatch loss at step 10100: 0.034217
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.2%
# Minibatch loss at step 10150: 0.006779
# Minibatch accuracy: 100.0%
# Validation accuracy: 88.3%
# Minibatch loss at step 10200: 0.515726
# Minibatch accuracy: 68.8%
# Validation accuracy: 88.9%
# Minibatch loss at step 10250: 0.143333
# Minibatch accuracy: 93.8%
# Validation accuracy: 87.9%
# Minibatch loss at step 10300: 0.659683
# Minibatch accuracy: 81.2%
# Validation accuracy: 88.4%
# Minibatch loss at step 10350: 0.111301
# Minibatch accuracy: 100.0%
# Validation accuracy: 88.8%
# Minibatch loss at step 10400: 0.418976
# Minibatch accuracy: 87.5%
# Validation accuracy: 89.0%
# Minibatch loss at step 10450: 0.645348
# Minibatch accuracy: 81.2%
# Validation accuracy: 89.1%
# Minibatch loss at step 10500: 0.364189
# Minibatch accuracy: 87.5%
# Validation accuracy: 88.9%
# Minibatch loss at step 10550: 0.269467
# Minibatch accuracy: 87.5%
# Validation accuracy: 88.3%
# Minibatch loss at step 10600: 0.839454
# Minibatch accuracy: 62.5%
# Validation accuracy: 88.3%
# Minibatch loss at step 10650: 0.201449
# Minibatch accuracy: 93.8%
# Validation accuracy: 87.9%
# Minibatch loss at step 10700: 0.170986
# Minibatch accuracy: 93.8%
# Validation accuracy: 87.8%
# Minibatch loss at step 10750: 0.243864
# Minibatch accuracy: 81.2%
# Validation accuracy: 87.9%
# Minibatch loss at step 10800: 0.415412
# Minibatch accuracy: 87.5%
# Validation accuracy: 88.7%
# Minibatch loss at step 10850: 0.208482
# Minibatch accuracy: 87.5%
# Validation accuracy: 89.2%
# Minibatch loss at step 10900: 0.239778
# Minibatch accuracy: 93.8%
# Validation accuracy: 87.6%
# Minibatch loss at step 10950: 0.384965
# Minibatch accuracy: 87.5%
# Validation accuracy: 88.9%
# Minibatch loss at step 11000: 0.443721
# Minibatch accuracy: 81.2%
# Validation accuracy: 88.5%
# Minibatch loss at step 11050: 0.238157
# Minibatch accuracy: 93.8%
# Validation accuracy: 89.1%
# Minibatch loss at step 11100: 0.195277
# Minibatch accuracy: 93.8%
# Validation accuracy: 88.2%
# Minibatch loss at step 11150: 0.184649
# Minibatch accuracy: 93.8%
# Validation accuracy: 88.9%
# Minibatch loss at step 11200: 0.245482
# Minibatch accuracy: 93.8%
# Validation accuracy: 89.3%
# Minibatch loss at step 11250: 1.126604
# Minibatch accuracy: 68.8%
# Validation accuracy: 88.8%
# Minibatch loss at step 11300: 0.174426
# Minibatch accuracy: 87.5%
# Validation accuracy: 88.7%
# Minibatch loss at step 11350: 0.295049
# Minibatch accuracy: 87.5%
# Validation accuracy: 89.0%
# Minibatch loss at step 11400: 0.270195
# Minibatch accuracy: 93.8%
# Validation accuracy: 89.0%
# Minibatch loss at step 11450: 1.085380
# Minibatch accuracy: 68.8%
# Validation accuracy: 87.6%
# Minibatch loss at step 11500: 0.254216
# Minibatch accuracy: 93.8%
# Validation accuracy: 88.3%
# Minibatch loss at step 11550: 0.261330
# Minibatch accuracy: 87.5%
# Validation accuracy: 89.6%
# Minibatch loss at step 11600: 0.572314
# Minibatch accuracy: 81.2%
# Validation accuracy: 90.0%
# Minibatch loss at step 11650: 0.251092
# Minibatch accuracy: 93.8%
# Validation accuracy: 88.4%
# Minibatch loss at step 11700: 0.225442
# Minibatch accuracy: 93.8%
# Validation accuracy: 88.9%
# Minibatch loss at step 11750: 0.373560
# Minibatch accuracy: 87.5%
# Validation accuracy: 88.4%
# Minibatch loss at step 11800: 0.078815
# Minibatch accuracy: 100.0%
# Validation accuracy: 88.7%
# Minibatch loss at step 11850: 0.272388
# Minibatch accuracy: 93.8%
# Validation accuracy: 88.2%
# Minibatch loss at step 11900: 0.241968
# Minibatch accuracy: 93.8%
# Validation accuracy: 88.5%
# Minibatch loss at step 11950: 0.155587
# Minibatch accuracy: 93.8%
# Validation accuracy: 89.4%
# Minibatch loss at step 12000: 0.269708
# Minibatch accuracy: 87.5%
# Validation accuracy: 88.8%
# Minibatch loss at step 12050: 0.539413
# Minibatch accuracy: 81.2%
# Validation accuracy: 89.0%
# Minibatch loss at step 12100: 1.471402
# Minibatch accuracy: 81.2%
# Validation accuracy: 89.3%
# Minibatch loss at step 12150: 0.302856
# Minibatch accuracy: 93.8%
# Validation accuracy: 89.4%
# Minibatch loss at step 12200: 0.188355
# Minibatch accuracy: 93.8%
# Validation accuracy: 90.1%
# Minibatch loss at step 12250: 0.183769
# Minibatch accuracy: 93.8%
# Validation accuracy: 89.0%
# Minibatch loss at step 12300: 0.917541
# Minibatch accuracy: 81.2%
# Validation accuracy: 88.9%
# Minibatch loss at step 12350: 0.695774
# Minibatch accuracy: 81.2%
# Validation accuracy: 88.5%
# Minibatch loss at step 12400: 0.433825
# Minibatch accuracy: 87.5%
# Validation accuracy: 88.4%
# Minibatch loss at step 12450: 0.157005
# Minibatch accuracy: 93.8%
# Validation accuracy: 88.3%
# Minibatch loss at step 12500: 0.295675
# Minibatch accuracy: 87.5%
# Validation accuracy: 88.7%
# Minibatch loss at step 12550: 0.274763
# Minibatch accuracy: 87.5%
# Validation accuracy: 88.5%
# Minibatch loss at step 12600: 0.326477
# Minibatch accuracy: 93.8%
# Validation accuracy: 88.5%
# Minibatch loss at step 12650: 0.503624
# Minibatch accuracy: 87.5%
# Validation accuracy: 88.6%
# Minibatch loss at step 12700: 0.196520
# Minibatch accuracy: 93.8%
# Validation accuracy: 88.1%
# Minibatch loss at step 12750: 0.274956
# Minibatch accuracy: 87.5%
# Validation accuracy: 88.2%
# Minibatch loss at step 12800: 0.083412
# Minibatch accuracy: 93.8%
# Validation accuracy: 88.6%
# Minibatch loss at step 12850: 0.387869
# Minibatch accuracy: 81.2%
# Validation accuracy: 87.7%
# Minibatch loss at step 12900: 0.049552
# Minibatch accuracy: 100.0%
# Validation accuracy: 88.8%
# Minibatch loss at step 12950: 0.202710
# Minibatch accuracy: 87.5%
# Validation accuracy: 88.9%
# Minibatch loss at step 13000: 0.266511
# Minibatch accuracy: 93.8%
# Validation accuracy: 88.5%
# Minibatch loss at step 13050: 0.113898
# Minibatch accuracy: 93.8%
# Validation accuracy: 89.1%
# Minibatch loss at step 13100: 0.258985
# Minibatch accuracy: 93.8%
# Validation accuracy: 88.3%
# Minibatch loss at step 13150: 0.535300
# Minibatch accuracy: 75.0%
# Validation accuracy: 88.4%
# Minibatch loss at step 13200: 0.359041
# Minibatch accuracy: 93.8%
# Validation accuracy: 89.0%
# Minibatch loss at step 13250: 0.471555
# Minibatch accuracy: 81.2%
# Validation accuracy: 89.4%
# Minibatch loss at step 13300: 0.350783
# Minibatch accuracy: 87.5%
# Validation accuracy: 89.1%
# Minibatch loss at step 13350: 0.255461
# Minibatch accuracy: 93.8%
# Validation accuracy: 89.1%
# Minibatch loss at step 13400: 0.071152
# Minibatch accuracy: 100.0%
# Validation accuracy: 88.6%
# Minibatch loss at step 13450: 0.112240
# Minibatch accuracy: 93.8%
# Validation accuracy: 88.7%
# Minibatch loss at step 13500: 0.766862
# Minibatch accuracy: 68.8%
# Validation accuracy: 88.4%
# Minibatch loss at step 13550: 0.270465
# Minibatch accuracy: 87.5%
# Validation accuracy: 88.4%
# Minibatch loss at step 13600: 0.220766
# Minibatch accuracy: 87.5%
# Validation accuracy: 89.5%
# Minibatch loss at step 13650: 0.391353
# Minibatch accuracy: 81.2%
# Validation accuracy: 89.1%
# Minibatch loss at step 13700: 0.498725
# Minibatch accuracy: 81.2%
# Validation accuracy: 89.1%
# Minibatch loss at step 13750: 0.098808
# Minibatch accuracy: 100.0%
# Validation accuracy: 88.6%
# Minibatch loss at step 13800: 0.487978
# Minibatch accuracy: 87.5%
# Validation accuracy: 88.8%
# Minibatch loss at step 13850: 0.621250
# Minibatch accuracy: 87.5%
# Validation accuracy: 88.6%
# Minibatch loss at step 13900: 0.164797
# Minibatch accuracy: 93.8%
# Validation accuracy: 88.1%
# Minibatch loss at step 13950: 0.236297
# Minibatch accuracy: 87.5%
# Validation accuracy: 88.7%
# Minibatch loss at step 14000: 0.488682
# Minibatch accuracy: 75.0%
# Validation accuracy: 88.0%
# Minibatch loss at step 14050: 0.281271
# Minibatch accuracy: 93.8%
# Validation accuracy: 88.4%
# Minibatch loss at step 14100: 0.119436
# Minibatch accuracy: 100.0%
# Validation accuracy: 88.2%
# Minibatch loss at step 14150: 0.633982
# Minibatch accuracy: 81.2%
# Validation accuracy: 89.1%
# Minibatch loss at step 14200: 0.462545
# Minibatch accuracy: 81.2%
# Validation accuracy: 88.9%
# Minibatch loss at step 14250: 0.263807
# Minibatch accuracy: 93.8%
# Validation accuracy: 88.9%
# Minibatch loss at step 14300: 0.234639
# Minibatch accuracy: 87.5%
# Validation accuracy: 89.2%
# Minibatch loss at step 14350: 0.687477
# Minibatch accuracy: 81.2%
# Validation accuracy: 90.0%
# Minibatch loss at step 14400: 0.047970
# Minibatch accuracy: 100.0%
# Validation accuracy: 88.4%
# Minibatch loss at step 14450: 0.204803
# Minibatch accuracy: 93.8%
# Validation accuracy: 89.5%
# Minibatch loss at step 14500: 0.430106
# Minibatch accuracy: 93.8%
# Validation accuracy: 89.2%
# Minibatch loss at step 14550: 0.102861
# Minibatch accuracy: 93.8%
# Validation accuracy: 88.9%
# Minibatch loss at step 14600: 0.086283
# Minibatch accuracy: 93.8%
# Validation accuracy: 89.7%
# Minibatch loss at step 14650: 0.457168
# Minibatch accuracy: 87.5%
# Validation accuracy: 89.8%
# Minibatch loss at step 14700: 0.134369
# Minibatch accuracy: 93.8%
# Validation accuracy: 89.8%
# Minibatch loss at step 14750: 0.473684
# Minibatch accuracy: 81.2%
# Validation accuracy: 89.1%
# Minibatch loss at step 14800: 0.460798
# Minibatch accuracy: 81.2%
# Validation accuracy: 89.1%
# Minibatch loss at step 14850: 0.494525
# Minibatch accuracy: 87.5%
# Validation accuracy: 89.6%
# Minibatch loss at step 14900: 0.109434
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.0%
# Minibatch loss at step 14950: 0.007077
# Minibatch accuracy: 100.0%
# Validation accuracy: 88.6%
# Minibatch loss at step 15000: 0.088832
# Minibatch accuracy: 93.8%
# Validation accuracy: 88.2%
# Minibatch loss at step 15050: 0.123091
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.6%
# Minibatch loss at step 15100: 0.122075
# Minibatch accuracy: 93.8%
# Validation accuracy: 89.1%
# Minibatch loss at step 15150: 0.490547
# Minibatch accuracy: 81.2%
# Validation accuracy: 88.5%
# Minibatch loss at step 15200: 0.726490
# Minibatch accuracy: 81.2%
# Validation accuracy: 87.9%
# Minibatch loss at step 15250: 0.497655
# Minibatch accuracy: 81.2%
# Validation accuracy: 89.4%
# Minibatch loss at step 15300: 0.524872
# Minibatch accuracy: 87.5%
# Validation accuracy: 89.1%
# Minibatch loss at step 15350: 0.108499
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.7%
# Minibatch loss at step 15400: 0.374520
# Minibatch accuracy: 93.8%
# Validation accuracy: 88.9%
# Minibatch loss at step 15450: 0.049497
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.1%
# Minibatch loss at step 15500: 0.065791
# Minibatch accuracy: 100.0%
# Validation accuracy: 88.8%
# Minibatch loss at step 15550: 0.244724
# Minibatch accuracy: 93.8%
# Validation accuracy: 88.8%
# Minibatch loss at step 15600: 0.413482
# Minibatch accuracy: 87.5%
# Validation accuracy: 88.9%
# Minibatch loss at step 15650: 0.304051
# Minibatch accuracy: 93.8%
# Validation accuracy: 88.3%
# Minibatch loss at step 15700: 0.487632
# Minibatch accuracy: 87.5%
# Validation accuracy: 89.0%
# Minibatch loss at step 15750: 0.335215
# Minibatch accuracy: 81.2%
# Validation accuracy: 88.7%
# Minibatch loss at step 15800: 0.585641
# Minibatch accuracy: 75.0%
# Validation accuracy: 88.8%
# Minibatch loss at step 15850: 0.698733
# Minibatch accuracy: 75.0%
# Validation accuracy: 88.9%
# Minibatch loss at step 15900: 0.703745
# Minibatch accuracy: 68.8%
# Validation accuracy: 88.1%
# Minibatch loss at step 15950: 0.331331
# Minibatch accuracy: 87.5%
# Validation accuracy: 87.6%
# Minibatch loss at step 16000: 0.152286
# Minibatch accuracy: 93.8%
# Validation accuracy: 88.4%
# Minibatch loss at step 16050: 0.362430
# Minibatch accuracy: 87.5%
# Validation accuracy: 88.1%
# Minibatch loss at step 16100: 0.630725
# Minibatch accuracy: 81.2%
# Validation accuracy: 88.9%
# Minibatch loss at step 16150: 0.065396
# Minibatch accuracy: 93.8%
# Validation accuracy: 89.4%
# Minibatch loss at step 16200: 0.368411
# Minibatch accuracy: 87.5%
# Validation accuracy: 88.6%
# Minibatch loss at step 16250: 0.086042
# Minibatch accuracy: 100.0%
# Validation accuracy: 88.7%
# Minibatch loss at step 16300: 0.218482
# Minibatch accuracy: 87.5%
# Validation accuracy: 88.6%
# Minibatch loss at step 16350: 0.427783
# Minibatch accuracy: 81.2%
# Validation accuracy: 89.2%
# Minibatch loss at step 16400: 0.625751
# Minibatch accuracy: 87.5%
# Validation accuracy: 89.4%
# Minibatch loss at step 16450: 0.452926
# Minibatch accuracy: 81.2%
# Validation accuracy: 89.5%
# Minibatch loss at step 16500: 0.183567
# Minibatch accuracy: 93.8%
# Validation accuracy: 89.1%
# Minibatch loss at step 16550: 0.728105
# Minibatch accuracy: 87.5%
# Validation accuracy: 89.0%
# Minibatch loss at step 16600: 0.760271
# Minibatch accuracy: 75.0%
# Validation accuracy: 89.8%
# Minibatch loss at step 16650: 0.178480
# Minibatch accuracy: 93.8%
# Validation accuracy: 89.3%
# Minibatch loss at step 16700: 0.278712
# Minibatch accuracy: 93.8%
# Validation accuracy: 88.2%
# Minibatch loss at step 16750: 0.172535
# Minibatch accuracy: 93.8%
# Validation accuracy: 89.5%
# Minibatch loss at step 16800: 0.327583
# Minibatch accuracy: 87.5%
# Validation accuracy: 88.8%
# Minibatch loss at step 16850: 0.116254
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.0%
# Minibatch loss at step 16900: 0.040521
# Minibatch accuracy: 100.0%
# Validation accuracy: 87.8%
# Minibatch loss at step 16950: 0.163546
# Minibatch accuracy: 93.8%
# Validation accuracy: 88.6%
# Minibatch loss at step 17000: 0.755749
# Minibatch accuracy: 75.0%
# Validation accuracy: 88.4%
# Minibatch loss at step 17050: 0.199339
# Minibatch accuracy: 93.8%
# Validation accuracy: 88.6%
# Minibatch loss at step 17100: 0.265312
# Minibatch accuracy: 93.8%
# Validation accuracy: 89.4%
# Minibatch loss at step 17150: 0.019701
# Minibatch accuracy: 100.0%
# Validation accuracy: 88.8%
# Minibatch loss at step 17200: 0.168386
# Minibatch accuracy: 93.8%
# Validation accuracy: 88.9%
# Minibatch loss at step 17250: 0.341308
# Minibatch accuracy: 87.5%
# Validation accuracy: 89.1%
# Minibatch loss at step 17300: 0.650895
# Minibatch accuracy: 81.2%
# Validation accuracy: 89.0%
# Minibatch loss at step 17350: 0.505893
# Minibatch accuracy: 87.5%
# Validation accuracy: 88.9%
# Minibatch loss at step 17400: 0.434217
# Minibatch accuracy: 81.2%
# Validation accuracy: 89.2%
# Minibatch loss at step 17450: 0.351378
# Minibatch accuracy: 87.5%
# Validation accuracy: 89.3%
# Minibatch loss at step 17500: 0.409641
# Minibatch accuracy: 87.5%
# Validation accuracy: 89.7%
# Minibatch loss at step 17550: 0.292610
# Minibatch accuracy: 87.5%
# Validation accuracy: 88.7%
# Minibatch loss at step 17600: 0.647365
# Minibatch accuracy: 87.5%
# Validation accuracy: 89.3%
# Minibatch loss at step 17650: 1.196442
# Minibatch accuracy: 75.0%
# Validation accuracy: 89.6%
# Minibatch loss at step 17700: 0.668901
# Minibatch accuracy: 75.0%
# Validation accuracy: 88.5%
# Minibatch loss at step 17750: 0.570609
# Minibatch accuracy: 87.5%
# Validation accuracy: 89.6%
# Minibatch loss at step 17800: 0.154156
# Minibatch accuracy: 93.8%
# Validation accuracy: 89.9%
# Minibatch loss at step 17850: 0.230834
# Minibatch accuracy: 93.8%
# Validation accuracy: 89.9%
# Minibatch loss at step 17900: 0.038880
# Minibatch accuracy: 100.0%
# Validation accuracy: 88.9%
# Minibatch loss at step 17950: 0.097639
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.2%
# Minibatch loss at step 18000: 0.006853
# Minibatch accuracy: 100.0%
# Validation accuracy: 88.2%
# Minibatch loss at step 18050: 0.529870
# Minibatch accuracy: 87.5%
# Validation accuracy: 88.9%
# Minibatch loss at step 18100: 0.109136
# Minibatch accuracy: 93.8%
# Validation accuracy: 89.3%
# Minibatch loss at step 18150: 0.263416
# Minibatch accuracy: 93.8%
# Validation accuracy: 88.8%
# Minibatch loss at step 18200: 0.196363
# Minibatch accuracy: 93.8%
# Validation accuracy: 89.2%
# Minibatch loss at step 18250: 0.047941
# Minibatch accuracy: 100.0%
# Validation accuracy: 88.1%
# Minibatch loss at step 18300: 0.395610
# Minibatch accuracy: 87.5%
# Validation accuracy: 89.0%
# Minibatch loss at step 18350: 0.453933
# Minibatch accuracy: 87.5%
# Validation accuracy: 89.4%
# Minibatch loss at step 18400: 0.161922
# Minibatch accuracy: 93.8%
# Validation accuracy: 89.4%
# Minibatch loss at step 18450: 0.066989
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.7%
# Minibatch loss at step 18500: 0.259494
# Minibatch accuracy: 93.8%
# Validation accuracy: 89.5%
# Minibatch loss at step 18550: 0.384747
# Minibatch accuracy: 87.5%
# Validation accuracy: 88.9%
# Minibatch loss at step 18600: 0.272480
# Minibatch accuracy: 87.5%
# Validation accuracy: 88.3%
# Minibatch loss at step 18650: 0.240742
# Minibatch accuracy: 93.8%
# Validation accuracy: 88.1%
# Minibatch loss at step 18700: 0.198150
# Minibatch accuracy: 93.8%
# Validation accuracy: 89.5%
# Minibatch loss at step 18750: 0.089897
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.0%
# Minibatch loss at step 18800: 0.046705
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.6%
# Minibatch loss at step 18850: 0.205550
# Minibatch accuracy: 93.8%
# Validation accuracy: 89.3%
# Minibatch loss at step 18900: 0.110113
# Minibatch accuracy: 93.8%
# Validation accuracy: 89.0%
# Minibatch loss at step 18950: 0.066518
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.7%
# Minibatch loss at step 19000: 0.057935
# Minibatch accuracy: 100.0%
# Validation accuracy: 88.4%
# Minibatch loss at step 19050: 0.429741
# Minibatch accuracy: 93.8%
# Validation accuracy: 88.0%
# Minibatch loss at step 19100: 0.556973
# Minibatch accuracy: 81.2%
# Validation accuracy: 88.0%
# Minibatch loss at step 19150: 0.328385
# Minibatch accuracy: 93.8%
# Validation accuracy: 88.8%
# Minibatch loss at step 19200: 0.085201
# Minibatch accuracy: 100.0%
# Validation accuracy: 88.2%
# Minibatch loss at step 19250: 0.542965
# Minibatch accuracy: 87.5%
# Validation accuracy: 88.7%
# Minibatch loss at step 19300: 0.589436
# Minibatch accuracy: 75.0%
# Validation accuracy: 88.6%
# Minibatch loss at step 19350: 0.305583
# Minibatch accuracy: 87.5%
# Validation accuracy: 88.2%
# Minibatch loss at step 19400: 0.012609
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.2%
# Minibatch loss at step 19450: 0.449999
# Minibatch accuracy: 75.0%
# Validation accuracy: 89.7%
# Minibatch loss at step 19500: 0.763746
# Minibatch accuracy: 93.8%
# Validation accuracy: 88.7%
# Minibatch loss at step 19550: 0.227886
# Minibatch accuracy: 93.8%
# Validation accuracy: 88.6%
# Minibatch loss at step 19600: 0.281402
# Minibatch accuracy: 87.5%
# Validation accuracy: 88.8%
# Minibatch loss at step 19650: 0.412724
# Minibatch accuracy: 81.2%
# Validation accuracy: 88.4%
# Minibatch loss at step 19700: 0.358684
# Minibatch accuracy: 87.5%
# Validation accuracy: 89.2%
# Minibatch loss at step 19750: 1.026806
# Minibatch accuracy: 62.5%
# Validation accuracy: 89.0%
# Minibatch loss at step 19800: 0.529169
# Minibatch accuracy: 87.5%
# Validation accuracy: 88.2%
# Minibatch loss at step 19850: 0.412510
# Minibatch accuracy: 81.2%
# Validation accuracy: 90.0%
# Minibatch loss at step 19900: 0.026200
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.6%
# Minibatch loss at step 19950: 0.366217
# Minibatch accuracy: 81.2%
# Validation accuracy: 89.0%
# Minibatch loss at step 20000: 0.175762
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.1%
# Test accuracy: 94.7%

# %% [markdown]
# The accuracy is good but not as good as the 3 - layer network from the previous assignment.
#
# The next version of the net uses dropout and learning rate decay:

# %%
batch_size = 16
patch_size = 5
depth = 16
num_hidden = 64
beta_regul = 1e-3
drop_out = 0.5

graph = tf.Graph()

with graph.as_default():

  # Input data.
  tf_train_dataset = tf.placeholder(
    tf.float32, shape=(batch_size, image_size, image_size, num_channels))
  tf_train_labels = tf.placeholder(tf.float32, shape=(batch_size, num_labels))
  tf_valid_dataset = tf.constant(valid_dataset)
  tf_test_dataset = tf.constant(test_dataset)
  global_step = tf.Variable(0)
  
  # Variables.
  layer1_weights = tf.Variable(tf.truncated_normal(
      [patch_size, patch_size, num_channels, depth], stddev=0.1))
  layer1_biases = tf.Variable(tf.zeros([depth]))
  layer2_weights = tf.Variable(tf.truncated_normal(
      [patch_size, patch_size, depth, depth], stddev=0.1))
  layer2_biases = tf.Variable(tf.constant(1.0, shape=[depth]))
  size3 = ((image_size - patch_size + 1) // 2 - patch_size + 1) // 2
  layer3_weights = tf.Variable(tf.truncated_normal(
      [size3 * size3 * depth, num_hidden], stddev=0.1))
  layer3_biases = tf.Variable(tf.constant(1.0, shape=[num_hidden]))
  layer4_weights = tf.Variable(tf.truncated_normal(
      [num_hidden, num_hidden], stddev=0.1))
  layer4_biases = tf.Variable(tf.constant(1.0, shape=[num_hidden]))
  layer5_weights = tf.Variable(tf.truncated_normal(
      [num_hidden, num_labels], stddev=0.1))
  layer5_biases = tf.Variable(tf.constant(1.0, shape=[num_labels]))
  
  # Model.
  def model(data, keep_prob):
    # C1 input 28 x 28
    conv1 = tf.nn.conv2d(data, layer1_weights, [1, 1, 1, 1], padding='VALID')
    bias1 = tf.nn.relu(conv1 + layer1_biases)
    # S2 input 24 x 24
    pool2 = tf.nn.avg_pool(bias1, [1, 2, 2, 1], [1, 2, 2, 1], padding='VALID')
    # C3 input 12 x 12
    conv3 = tf.nn.conv2d(pool2, layer2_weights, [1, 1, 1, 1], padding='VALID')
    bias3 = tf.nn.relu(conv3 + layer2_biases)
    # S4 input 8 x 8
    pool4 = tf.nn.avg_pool(bias3, [1, 2, 2, 1], [1, 2, 2, 1], padding='VALID')
    # F5 input 4 x 4
    shape = pool4.get_shape().as_list()
    reshape = tf.reshape(pool4, [shape[0], shape[1] * shape[2] * shape[3]])
    hidden5 = tf.nn.relu(tf.matmul(reshape, layer3_weights) + layer3_biases)
    # F6
    drop5 = tf.nn.dropout(hidden5, keep_prob)
    hidden6 = tf.nn.relu(tf.matmul(hidden5, layer4_weights) + layer4_biases)
    drop6 = tf.nn.dropout(hidden6, keep_prob)
    return tf.matmul(drop6, layer5_weights) + layer5_biases
  
  # Training computation.
  logits = model(tf_train_dataset, drop_out)
  loss = tf.reduce_mean(
    tf.nn.softmax_cross_entropy_with_logits(logits = logits,labels= tf_train_labels))
    
  # Optimizer.
  learning_rate = tf.train.exponential_decay(0.05, global_step, 1000, 0.85, staircase=True)
  optimizer = tf.train.GradientDescentOptimizer(learning_rate).minimize(loss, global_step=global_step)
  
  # Predictions for the training, validation, and test data.
  train_prediction = tf.nn.softmax(logits)
  valid_prediction = tf.nn.softmax(model(tf_valid_dataset, 1.0))
  test_prediction = tf.nn.softmax(model(tf_test_dataset, 1.0))

# %%
num_steps = 5001

with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print('Initialized')
  for step in range(num_steps):
    offset = (step * batch_size) % (train_labels.shape[0] - batch_size)
    batch_data = train_dataset[offset:(offset + batch_size), :, :, :]
    batch_labels = train_labels[offset:(offset + batch_size), :]
    feed_dict = {tf_train_dataset : batch_data, tf_train_labels : batch_labels}
    _, l, predictions = session.run(
      [optimizer, loss, train_prediction], feed_dict=feed_dict)
    if (step % 50 == 0):
      print('Minibatch loss at step %d: %f' % (step, l))
      print('Minibatch accuracy: %.1f%%' % accuracy(predictions, batch_labels))
      print('Validation accuracy: %.1f%%' % accuracy(
        valid_prediction.eval(), valid_labels))
  print('Test accuracy: %.1f%%' % accuracy(test_prediction.eval(), test_labels))
# Out:
# Initialized
# Minibatch loss at step 0: 3.356557
# Minibatch accuracy: 6.2%
# Validation accuracy: 10.0%
# Minibatch loss at step 50: 1.956727
# Minibatch accuracy: 50.0%
# Validation accuracy: 26.4%
# Minibatch loss at step 100: 1.888036
# Minibatch accuracy: 37.5%
# Validation accuracy: 57.2%
# Minibatch loss at step 150: 1.248670
# Minibatch accuracy: 56.2%
# Validation accuracy: 55.8%
# Minibatch loss at step 200: 1.449604
# Minibatch accuracy: 43.8%
# Validation accuracy: 64.1%
# Minibatch loss at step 250: 1.002225
# Minibatch accuracy: 56.2%
# Validation accuracy: 62.7%
# Minibatch loss at step 300: 0.997521
# Minibatch accuracy: 75.0%
# Validation accuracy: 68.6%
# Minibatch loss at step 350: 1.238865
# Minibatch accuracy: 62.5%
# Validation accuracy: 69.0%
# Minibatch loss at step 400: 1.405753
# Minibatch accuracy: 50.0%
# Validation accuracy: 70.3%
# Minibatch loss at step 450: 1.216027
# Minibatch accuracy: 68.8%
# Validation accuracy: 74.3%
# Minibatch loss at step 500: 0.965257
# Minibatch accuracy: 75.0%
# Validation accuracy: 71.8%
# Minibatch loss at step 550: 0.684723
# Minibatch accuracy: 87.5%
# Validation accuracy: 77.2%
# Minibatch loss at step 600: 0.634352
# Minibatch accuracy: 75.0%
# Validation accuracy: 77.2%
# Minibatch loss at step 650: 1.323570
# Minibatch accuracy: 62.5%
# Validation accuracy: 77.7%
# Minibatch loss at step 700: 1.045641
# Minibatch accuracy: 62.5%
# Validation accuracy: 75.6%
# Minibatch loss at step 750: 0.732314
# Minibatch accuracy: 81.2%
# Validation accuracy: 78.8%
# Minibatch loss at step 800: 0.565903
# Minibatch accuracy: 93.8%
# Validation accuracy: 78.6%
# Minibatch loss at step 850: 1.430522
# Minibatch accuracy: 56.2%
# Validation accuracy: 77.5%
# Minibatch loss at step 900: 1.004338
# Minibatch accuracy: 81.2%
# Validation accuracy: 78.4%
# Minibatch loss at step 950: 1.235780
# Minibatch accuracy: 50.0%
# Validation accuracy: 76.7%
# Minibatch loss at step 1000: 0.275276
# Minibatch accuracy: 93.8%
# Validation accuracy: 78.3%
# Minibatch loss at step 1050: 0.801046
# Minibatch accuracy: 68.8%
# Validation accuracy: 79.1%
# Minibatch loss at step 1100: 0.837284
# Minibatch accuracy: 81.2%
# Validation accuracy: 79.0%
# Minibatch loss at step 1150: 0.642281
# Minibatch accuracy: 81.2%
# Validation accuracy: 78.3%
# Minibatch loss at step 1200: 0.748091
# Minibatch accuracy: 87.5%
# Validation accuracy: 79.9%
# Minibatch loss at step 1250: 0.668518
# Minibatch accuracy: 81.2%
# Validation accuracy: 79.9%
# Minibatch loss at step 1300: 0.558262
# Minibatch accuracy: 81.2%
# Validation accuracy: 81.1%
# Minibatch loss at step 1350: 0.700695
# Minibatch accuracy: 81.2%
# Validation accuracy: 80.5%
# Minibatch loss at step 1400: 1.247748
# Minibatch accuracy: 68.8%
# Validation accuracy: 79.8%
# Minibatch loss at step 1450: 0.888731
# Minibatch accuracy: 81.2%
# Validation accuracy: 80.0%
# Minibatch loss at step 1500: 0.846074
# Minibatch accuracy: 56.2%
# Validation accuracy: 81.4%
# Minibatch loss at step 1550: 1.002287
# Minibatch accuracy: 68.8%
# Validation accuracy: 79.9%
# Minibatch loss at step 1600: 1.256522
# Minibatch accuracy: 56.2%
# Validation accuracy: 81.0%
# Minibatch loss at step 1650: 1.140271
# Minibatch accuracy: 75.0%
# Validation accuracy: 80.3%
# Minibatch loss at step 1700: 1.459837
# Minibatch accuracy: 62.5%
# Validation accuracy: 80.9%
# Minibatch loss at step 1750: 1.000576
# Minibatch accuracy: 68.8%
# Validation accuracy: 79.1%
# Minibatch loss at step 1800: 0.717377
# Minibatch accuracy: 75.0%
# Validation accuracy: 81.8%
# Minibatch loss at step 1850: 0.599981
# Minibatch accuracy: 81.2%
# Validation accuracy: 81.3%
# Minibatch loss at step 1900: 0.672759
# Minibatch accuracy: 87.5%
# Validation accuracy: 80.5%
# Minibatch loss at step 1950: 0.879970
# Minibatch accuracy: 75.0%
# Validation accuracy: 81.1%
# Minibatch loss at step 2000: 0.524785
# Minibatch accuracy: 81.2%
# Validation accuracy: 82.2%
# Minibatch loss at step 2050: 0.509977
# Minibatch accuracy: 87.5%
# Validation accuracy: 82.3%
# Minibatch loss at step 2100: 1.154608
# Minibatch accuracy: 62.5%
# Validation accuracy: 82.0%
# Minibatch loss at step 2150: 1.111353
# Minibatch accuracy: 75.0%
# Validation accuracy: 81.9%
# Minibatch loss at step 2200: 0.949016
# Minibatch accuracy: 62.5%
# Validation accuracy: 82.7%
# Minibatch loss at step 2250: 1.115391
# Minibatch accuracy: 68.8%
# Validation accuracy: 81.6%
# Minibatch loss at step 2300: 0.656624
# Minibatch accuracy: 75.0%
# Validation accuracy: 81.4%
# Minibatch loss at step 2350: 1.116702
# Minibatch accuracy: 75.0%
# Validation accuracy: 82.7%
# Minibatch loss at step 2400: 0.503535
# Minibatch accuracy: 81.2%
# Validation accuracy: 82.2%
# Minibatch loss at step 2450: 0.748628
# Minibatch accuracy: 75.0%
# Validation accuracy: 82.7%
# Minibatch loss at step 2500: 0.629805
# Minibatch accuracy: 75.0%
# Validation accuracy: 82.5%
# Minibatch loss at step 2550: 0.495857
# Minibatch accuracy: 81.2%
# Validation accuracy: 83.0%
# Minibatch loss at step 2600: 0.661814
# Minibatch accuracy: 81.2%
# Validation accuracy: 82.3%
# Minibatch loss at step 2650: 0.927757
# Minibatch accuracy: 62.5%
# Validation accuracy: 82.7%
# Minibatch loss at step 2700: 0.532899
# Minibatch accuracy: 81.2%
# Validation accuracy: 83.4%
# Minibatch loss at step 2750: 0.116904
# Minibatch accuracy: 100.0%
# Validation accuracy: 83.9%
# Minibatch loss at step 2800: 1.109725
# Minibatch accuracy: 68.8%
# Validation accuracy: 83.9%
# Minibatch loss at step 2850: 0.444227
# Minibatch accuracy: 87.5%
# Validation accuracy: 82.9%
# Minibatch loss at step 2900: 0.266738
# Minibatch accuracy: 93.8%
# Validation accuracy: 83.1%
# Minibatch loss at step 2950: 0.389883
# Minibatch accuracy: 87.5%
# Validation accuracy: 82.7%
# Minibatch loss at step 3000: 0.300915
# Minibatch accuracy: 93.8%
# Validation accuracy: 82.2%
# Minibatch loss at step 3050: 0.677059
# Minibatch accuracy: 81.2%
# Validation accuracy: 83.0%
# Minibatch loss at step 3100: 0.464299
# Minibatch accuracy: 87.5%
# Validation accuracy: 83.5%
# Minibatch loss at step 3150: 0.420947
# Minibatch accuracy: 87.5%
# Validation accuracy: 83.6%
# Minibatch loss at step 3200: 0.044606
# Minibatch accuracy: 100.0%
# Validation accuracy: 84.0%
# Minibatch loss at step 3250: 0.512165
# Minibatch accuracy: 93.8%
# Validation accuracy: 82.8%
# Minibatch loss at step 3300: 0.277065
# Minibatch accuracy: 93.8%
# Validation accuracy: 83.2%
# Minibatch loss at step 3350: 0.589854
# Minibatch accuracy: 75.0%
# Validation accuracy: 84.0%
# Minibatch loss at step 3400: 0.753571
# Minibatch accuracy: 68.8%
# Validation accuracy: 83.9%
# Minibatch loss at step 3450: 0.402536
# Minibatch accuracy: 87.5%
# Validation accuracy: 83.8%
# Minibatch loss at step 3500: 0.427686
# Minibatch accuracy: 87.5%
# Validation accuracy: 83.2%
# Minibatch loss at step 3550: 1.291564
# Minibatch accuracy: 62.5%
# Validation accuracy: 82.9%
# Minibatch loss at step 3600: 0.467104
# Minibatch accuracy: 87.5%
# Validation accuracy: 83.8%
# Minibatch loss at step 3650: 0.352810
# Minibatch accuracy: 87.5%
# Validation accuracy: 84.3%
# Minibatch loss at step 3700: 0.941478
# Minibatch accuracy: 75.0%
# Validation accuracy: 83.5%
# Minibatch loss at step 3750: 0.645056
# Minibatch accuracy: 62.5%
# Validation accuracy: 83.6%
# Minibatch loss at step 3800: 0.570507
# Minibatch accuracy: 93.8%
# Validation accuracy: 84.1%
# Minibatch loss at step 3850: 0.214946
# Minibatch accuracy: 87.5%
# Validation accuracy: 83.8%
# Minibatch loss at step 3900: 0.846027
# Minibatch accuracy: 75.0%
# Validation accuracy: 84.3%
# Minibatch loss at step 3950: 0.488634
# Minibatch accuracy: 81.2%
# Validation accuracy: 84.5%
# Minibatch loss at step 4000: 0.427704
# Minibatch accuracy: 87.5%
# Validation accuracy: 84.6%
# Minibatch loss at step 4050: 0.530176
# Minibatch accuracy: 81.2%
# Validation accuracy: 84.9%
# Minibatch loss at step 4100: 0.414544
# Minibatch accuracy: 81.2%
# Validation accuracy: 85.1%
# Minibatch loss at step 4150: 0.911583
# Minibatch accuracy: 75.0%
# Validation accuracy: 84.2%
# Minibatch loss at step 4200: 0.483638
# Minibatch accuracy: 81.2%
# Validation accuracy: 84.2%
# Minibatch loss at step 4250: 0.686334
# Minibatch accuracy: 68.8%
# Validation accuracy: 83.9%
# Minibatch loss at step 4300: 0.289962
# Minibatch accuracy: 93.8%
# Validation accuracy: 84.9%
# Minibatch loss at step 4350: 0.957203
# Minibatch accuracy: 68.8%
# Validation accuracy: 84.8%
# Minibatch loss at step 4400: 0.188703
# Minibatch accuracy: 93.8%
# Validation accuracy: 84.7%
# Minibatch loss at step 4450: 0.551452
# Minibatch accuracy: 81.2%
# Validation accuracy: 85.3%
# Minibatch loss at step 4500: 0.667953
# Minibatch accuracy: 81.2%
# Validation accuracy: 85.1%
# Minibatch loss at step 4550: 0.423451
# Minibatch accuracy: 87.5%
# Validation accuracy: 84.2%
# Minibatch loss at step 4600: 0.445856
# Minibatch accuracy: 81.2%
# Validation accuracy: 84.5%
# Minibatch loss at step 4650: 0.396966
# Minibatch accuracy: 87.5%
# Validation accuracy: 84.2%
# Minibatch loss at step 4700: 0.755893
# Minibatch accuracy: 75.0%
# Validation accuracy: 84.4%
# Minibatch loss at step 4750: 0.550860
# Minibatch accuracy: 87.5%
# Validation accuracy: 84.8%
# Minibatch loss at step 4800: 0.206978
# Minibatch accuracy: 93.8%
# Validation accuracy: 85.3%
# Minibatch loss at step 4850: 0.327899
# Minibatch accuracy: 93.8%
# Validation accuracy: 84.9%
# Minibatch loss at step 4900: 0.605137
# Minibatch accuracy: 87.5%
# Validation accuracy: 85.3%
# Minibatch loss at step 4950: 0.304758
# Minibatch accuracy: 87.5%
# Validation accuracy: 84.9%
# Minibatch loss at step 5000: 0.616654
# Minibatch accuracy: 75.0%
# Validation accuracy: 85.4%
# Test accuracy: 91.7%
